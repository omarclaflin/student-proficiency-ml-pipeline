# %%
#make new pipelien project

import shutil

template_folder = "pipeline_template"
new_project_name = "item_param_calc_50"  # Change this to your desired name

shutil.copytree(template_folder, new_project_name)
# Out:
# 'item_param_calc_50'
