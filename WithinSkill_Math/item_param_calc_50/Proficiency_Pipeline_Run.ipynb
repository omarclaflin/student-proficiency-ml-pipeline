# %%
#RESTART of IP CALC - ~1500 skills deep


# !df -h
# !rm -rf StudentProficiencyData_Math_yearOfData
# !df -h

# %%
#import Pipeline
import os, sys
current_dir = os.getcwd()
base_path = os.path.abspath(os.path.join(current_dir, '../..'))
sys.path.append(os.path.join(base_path, 'ProficiencyModelTrainingPipeline'))
print(sys.path)

import ProficiencyModelTrainingPipeline
# Out:
# ['/home/ec2-user/anaconda3/envs/python3/lib/python310.zip', '/home/ec2-user/anaconda3/envs/python3/lib/python3.10', '/home/ec2-user/anaconda3/envs/python3/lib/python3.10/lib-dynload', '', '/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages', '/home/ec2-user/SageMaker/[REDACTED]AppliedScience/Omar/ProficiencyModelTrainingPipeline']
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/xgboost/core.py:265: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc 2.28+) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
# !free -m
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:          70214        2684       43266           0       24263       66772
# Swap:             0           0           0

# %%
pipeline_id = '01312025_noSkillExplode'
feature_set_id='v50'
model_type = 'standard'
CorrectnessBinary=False

#Snowflake Data grab/destination folder
doSnowflakeETL=False
pullNewData = False
query_file = 'querytransformedtable.txt'
raw_data_folder_path = 'StudentProficiencyData_Math_yearOfData'
skillExplode = False #cut down on data requirements and this doesn't improve accuracy nor is it implemented by Eng

#set to 0 for only current performance (1 item); set greater to use more future windowing for conf modelling (only)
FUTURE_WINDOW=0

#Create a test train split on studentID; False: use existing testSIDs, trainSIDs
GenerateTestTrainSplit = False

# Recalculate IPs
ItemParameterCalculate = True

#Feature engineering on loaded data (IP JOIN, Event diff, cap values, etc)
FeatureEngineering=False
item_params_file = 'Math_ItemParameters_v5.csv'
#item_params_file = f"{item_params_file[:-4]}{'_binary' if CorrectnessBinary else '_continuous'}.csv"
# item_params_file = 'ELA_ItemParameters_3months.csv'
# item_params_file = 'ELA_ItemParameters_v3_continuous.csv'

#Proficiency model, scaler fit and export
#adjust this down for very large datasets 
ProficiencyModelFit=False
n_estimators=1
ItemAgnosticDoubleFit=False


SigmoidTransformOutput = False
SigmoidTransformOutputFit = False

#Confidence model fit and export
ConfidenceModelFit=False

#run inference on test set of data
InferenceModeOn= False
#toggle this off if we arleady feature-processed the test data to save time
InferenceModeFeatureEngineering = False

#run small amount of data
TestMode = False
smallInferenceRun=30

#scaler off by default now
#scalerFlag = False



ProficiencyModelTrainingPipeline.run_full_pipeline(pipeline_id=pipeline_id,
                  feature_set_id=feature_set_id,
                  model_type=model_type,
                                                   
                  CorrectnessBinary=CorrectnessBinary,
                  doSnowflakeETL=doSnowflakeETL,
                  skillExplode =skillExplode,
                  pullNewData=pullNewData,
                  query_file=query_file,
                  raw_data_folder_path=raw_data_folder_path,
                                                   
                  GenerateTestTrainSplit=GenerateTestTrainSplit,
                                                   
                  ItemParameterCalculate=ItemParameterCalculate,
                  item_params_file=item_params_file,
                                                   
                  FeatureEngineering=FeatureEngineering,
                                                   
                  ProficiencyModelFit=ProficiencyModelFit,
                  n_estimators=n_estimators,
                  ItemAgnosticDoubleFit=ItemAgnosticDoubleFit,                                                   
                                                   
                  SigmoidTransformOutputFit=SigmoidTransformOutputFit,
                  SigmoidTransformOutput=SigmoidTransformOutput,
                                                   
                  ConfidenceModelFit=ConfidenceModelFit,
                  InferenceModeOn=InferenceModeOn,
                  InferenceModeFeatureEngineering = InferenceModeFeatureEngineering,
                  TestMode=TestMode, 

                  smallInferenceRun=smallInferenceRun,
                                                   
                  FUTURE_WINDOW=FUTURE_WINDOW,
                  log_folder='.')
# Out:
# 2025-03-12 22:26:00,961 - Starting model training. Logs will be saved to ./ML_training_pipeline_log_01312025_noSkillExplode_v50_20250312_222600.txt
# 2025-03-12 22:26:00,962 - Pipeline Configuration:
# 2025-03-12 22:26:00,962 - pipeline_id: 01312025_noSkillExplode
# 2025-03-12 22:26:00,962 - feature_set_id: v50
# 2025-03-12 22:26:00,963 - model_type: standard
# 2025-03-12 22:26:00,963 - doSnowflakeETL: False
# 2025-03-12 22:26:00,964 - skillExplode: False
# 2025-03-12 22:26:00,964 - CorrectnessBinary: False
# 2025-03-12 22:26:00,964 - ItemAgnostic: False
# 2025-03-12 22:26:00,965 - ItemAgnosticFit: False
# 2025-03-12 22:26:00,965 - ItemAgnosticDoubleFit: False
# 2025-03-12 22:26:00,966 - F1ObjectiveMeasure: False
# 2025-03-12 22:26:00,966 - SigmoidTransformOutputFit: False
# 2025-03-12 22:26:00,966 - UseSigmoidTransform: False
# 2025-03-12 22:26:00,967 - SigmoidTransformOutput: False
# 2025-03-12 22:26:00,967 - pullNewData: False
# 2025-03-12 22:26:00,968 - query_file: querytransformedtable.txt
# 2025-03-12 22:26:00,968 - raw_data_folder_path: StudentProficiencyData_Math_yearOfData
# 2025-03-12 22:26:00,968 - GenerateTestTrainSplit: False
# 2025-03-12 22:26:00,968 - ItemParameterCalculate: True
# 2025-03-12 22:26:00,969 - item_params_file: Math_ItemParameters_v5.csv
# 2025-03-12 22:26:00,969 - FeatureEngineering: False
# 2025-03-12 22:26:00,969 - ProficiencyModelFit: False
# 2025-03-12 22:26:00,970 - ConfidenceModelFit: False
# 2025-03-12 22:26:00,970 - InferenceModeOn: False
# 2025-03-12 22:26:00,970 - InferenceModeFeatureEngineering: False
# 2025-03-12 22:26:00,971 - TestMode: False
# 2025-03-12 22:26:00,971 - n_estimators: 1
# 2025-03-12 22:26:00,971 - FUTURE_WINDOW: 0
# 2025-03-12 22:26:00,972 - scalerFlag: False
# 2025-03-12 22:26:00,972 - log_folder: .
# 2025-03-12 22:26:00,972 - Folder Locations for input data and output artifacts:
# 2025-03-12 22:26:00,973 - feature_engineering_output_folder: feature_engineered_train_parquets_v50/
# 2025-03-12 22:26:00,973 - proficiency_input_folder: feature_engineered_train_parquets_v50/
# 2025-03-12 22:26:00,973 - proficiency_model_output_folder: proficiency_model_01312025_noSkillExplode_v50_standard
# 2025-03-12 22:26:00,974 - confidence_input_folder: feature_engineered_train_parquets_v50/
# 2025-03-12 22:26:00,974 - confidence_model_output_folder: confidence_model_01312025_noSkillExplode_v50_standard
# 2025-03-12 22:26:00,974 - proficiency_model_file : proficiency_model_01312025_noSkillExplode_v50_standard/xgb_model.json
# 2025-03-12 22:26:00,977 - column_names.txt (from raw query): ['STUDENTID', 'SKILL', 'QUESTIONID', 'OCCURREDAT', 'CORRECTNESS', 'DURATIONSECONDS', 'ANSWERPOSITIONINSESSION', 'EVENT_RANK', 'QUESTIONID_LAG_1', 'QUESTIONID_LAG_2', 'QUESTIONID_LAG_3', 'QUESTIONID_LAG_4', 'QUESTIONID_LAG_5', 'QUESTIONID_LAG_6', 'QUESTIONID_LAG_7', 'QUESTIONID_LAG_8', 'QUESTIONID_LAG_9', 'QUESTIONID_LAG_10', 'OCCURREDAT_LAG_1', 'OCCURREDAT_LAG_2', 'OCCURREDAT_LAG_3', 'OCCURREDAT_LAG_4', 'OCCURREDAT_LAG_5', 'OCCURREDAT_LAG_6', 'OCCURREDAT_LAG_7', 'OCCURREDAT_LAG_8', 'OCCURREDAT_LAG_9', 'OCCURREDAT_LAG_10', 'CORRECTNESS_LAG_1', 'CORRECTNESS_LAG_2', 'CORRECTNESS_LAG_3', 'CORRECTNESS_LAG_4', 'CORRECTNESS_LAG_5', 'CORRECTNESS_LAG_6', 'CORRECTNESS_LAG_7', 'CORRECTNESS_LAG_8', 'CORRECTNESS_LAG_9', 'CORRECTNESS_LAG_10', 'DURATIONSECONDS_LAG_1', 'DURATIONSECONDS_LAG_2', 'DURATIONSECONDS_LAG_3', 'DURATIONSECONDS_LAG_4', 'DURATIONSECONDS_LAG_5', 'DURATIONSECONDS_LAG_6', 'DURATIONSECONDS_LAG_7', 'DURATIONSECONDS_LAG_8', 'DURATIONSECONDS_LAG_9', 'DURATIONSECONDS_LAG_10', 'FUTURE_CORRECTNESS_LAG_1', 'FUTURE_CORRECTNESS_LAG_2', 'FUTURE_CORRECTNESS_LAG_3', 'FUTURE_CORRECTNESS_LAG_4', 'FUTURE_CORRECTNESS_LAG_5']
# 2025-03-12 22:26:00,979 - 844 files found.
# 2025-03-12 22:26:00,979 - Starting Item Param Calc.
# 2025-03-12 22:26:01,405 - Imported 1028974 studentids for IP Calc.
# 2025-03-12 22:26:01,496 - Starting IRT processing. Output: Math_ItemParameters_v5.csv, Version: 3.0
# 2025-03-12 22:26:01,496 - Number of training IDs: 1028974
# 2025-03-12 22:26:01,498 - Starting 33 cores for skill search.
# 2025-03-12 22:29:22,461 - Processed 100 out of 844 files. Current unique skills: 3023
# 2025-03-13 07:31:27,456 - Processed 700 out of 844 files. Current rows: 25784
# 2025-03-13 07:34:20,403 - Processed 800 out of 844 files. Current rows: 28718
# 2025-03-13 07:35:39,731 - Processed 844 out of 844 files. Current rows: 29468
# 2025-03-13 07:35:39,749 - Final shape for skill negvefnf: (29468, 3)
# 2025-03-13 07:35:39,752 - Loading time: 1483.49 seconds for 29468 rows after filtering
# 2025-03-13 07:35:39,788 - Table size: (3209, 129)
# 2025-03-13 07:35:39,789 - Solving for item parameters...
# large correctness values detected, normalizing table
# ot is nan or inf:  nan
# ot is nan or inf:  nan
# ot is nan or inf:  nan
# ot is nan or inf:  nan
# ot is nan or inf:  inf
# ot is nan or inf:  inf
# ot is nan or inf:  nan
# ot is nan or inf:  nan
# ot is nan or inf:  nan
# ot is nan or inf:  nan
# ot is nan or inf:  nan
# ot is nan or inf:  nan
# ot is nan or inf:  nan
# ot is nan or inf:  nan
# 2025-03-13 07:38:22,910 - Parameter calculation time: 163.12 seconds
# 2025-03-13 07:38:22,911 - NaNs in est params: 50 out of 129
# 2025-03-13 07:38:22,911 - NaNs in auc_roc: 33 out of 129
# 2025-03-13 07:38:22,912 - NaNs in optimal_threshold: 33 out of 129
# ot is nan or inf:  nan
# ot is nan or inf:  inf
# ot is nan or inf:  nan
# 2025-03-13 07:38:24,659 - Processing skill #21: 1526bea3647f4be0adac9c270a5142a8
# 2025-03-13 07:41:19,617 - Processed 100 out of 844 files. Current rows: 1255
# 2025-03-13 07:44:13,903 - Processed 200 out of 844 files. Current rows: 1976
# 2025-03-13 07:47:40,672 - Processed 300 out of 844 files. Current rows: 3436
# 2025-03-13 07:50:39,816 - Processed 400 out of 844 files. Current rows: 5069
# 2025-03-13 07:53:37,825 - Processed 500 out of 844 files. Current rows: 5534
# 2025-03-13 07:56:36,756 - Processed 600 out of 844 files. Current rows: 6094
# 2025-03-13 07:59:34,979 - Processed 700 out of 844 files. Current rows: 7371
# 2025-03-13 08:02:33,046 - Processed 800 out of 844 files. Current rows: 8385
# 2025-03-13 08:03:55,327 - Processed 844 out of 844 files. Current rows: 8767
# 2025-03-13 08:03:55,357 - Final shape for skill 1526bea3647f4be0adac9c270a5142a8: (8767, 3)
# 2025-03-13 08:03:55,362 - Loading time: 1530.70 seconds for 8767 rows after filtering
# 2025-03-13 08:03:55,388 - Table size: (1569, 131)
# 2025-03-13 08:03:55,388 - Solving for item parameters...
# large correctness values detected, normalizing table
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# ot is nan or inf:  inf
# ot is nan or inf:  inf
# 2025-03-13 08:05:57,456 - Parameter calculation time: 122.07 seconds
# 2025-03-13 08:05:57,456 - NaNs in est params: 81 out of 131
# 2025-03-13 08:05:57,457 - NaNs in auc_roc: 83 out of 131
# 2025-03-13 08:05:57,457 - NaNs in optimal_threshold: 81 out of 131
# 2025-03-13 08:05:59,212 - Processing skill #22: 987f63d82400e4119e54005056801da1
# 2025-03-13 08:08:56,603 - Processed 100 out of 844 files. Current rows: 1059
# 2025-03-13 08:11:53,976 - Processed 200 out of 844 files. Current rows: 1710
# 2025-03-13 08:14:53,288 - Processed 300 out of 844 files. Current rows: 2588
# 2025-03-13 08:17:57,125 - Processed 400 out of 844 files. Current rows: 3472
# 2025-03-13 08:20:55,743 - Processed 500 out of 844 files. Current rows: 4634
# 2025-03-13 08:23:53,319 - Processed 600 out of 844 files. Current rows: 5165
# 2025-03-13 08:26:51,955 - Processed 700 out of 844 files. Current rows: 6175
# 2025-03-13 08:29:50,149 - Processed 800 out of 844 files. Current rows: 6948
# 2025-03-13 08:31:14,687 - Processed 844 out of 844 files. Current rows: 7198
# 2025-03-13 08:31:14,702 - Final shape for skill 987f63d82400e4119e54005056801da1: (7198, 3)
# 2025-03-13 08:31:14,705 - Loading time: 1515.49 seconds for 7198 rows after filtering
# 2025-03-13 08:31:14,721 - Table size: (1432, 39)
# 2025-03-13 08:31:14,721 - Solving for item parameters...
# large correctness values detected, normalizing table
# 2025-03-13 08:31:53,232 - Parameter calculation time: 38.51 seconds
# 2025-03-13 08:31:54,984 - Processing skill #23: 99a4bfaa479de311b77c005056801da1
# 2025-03-13 08:34:52,964 - Processed 100 out of 844 files. Current rows: 120010
