# %% [markdown]
# #Run this script to start a new model project
#
# #/tools/ has some scripts to look at ECR, look at running endpoints, test running endpoints, etc
#
# #probably don't need any of them, just use the main script found in the project directory 'BuildAndDeployDockerImageToSagemakerEndpoint.ipynb' to set up a new endpoint (or do a rolling update)

# %%
new_project_folder = 'Math_student_proficiency_model'

# %%
import shutil
import os

# Define the source and destination paths
source_folder = 'custom_model_template'

# Check if the source folder exists
if os.path.exists(source_folder):
    # Copy the folder and its contents
    shutil.copytree(source_folder, new_project_folder)
    print(f"Folder '{source_folder}' copied to '{new_project_folder}' successfully.")
else:
    print(f"Source folder '{source_folder}' does not exist.")
# Out:
# Folder 'custom_model_template' copied to 'Math_student_proficiency_model' successfully.
